# %%
# %run ../cpch_source.py
import os
import time

# %%
np.random.seed(211)
#run script total of 3 times, for r=m=2, m=3, r=2, and r=m=3, in that order
m = 3
r = 3
N = 10000
power_iters = 100
total_iters = 100
mu_max = 4
mu_step = 0.2
alpha = 0.05

# %%
mu_grid = np.arange(0, mu_max + mu_step, mu_step)
def null_mu(m, r, mu_grid):
    '''
    generates list of n-length arrays of unique configurations under the null using mu_grid
    '''
    all_prods = list(itertools.product(mu_grid, repeat = m))
    null_cases = np.unique(np.array([sorted(i) for i in all_prods if sum(np.array(i) == 0.0) in np.arange(m-r+1, m+1, 1)]), axis = 0)
    return(null_cases)

# %%
mu_grid = np.arange(0, mu_max + mu_step, mu_step)
null_cases = null_mu(m, r, mu_grid)
num_null_cases = len(null_cases)
print(num_null_cases)
def calculate_cpch(null_case, power_iters, m, r):
    #for a given mu vector, generate data from that mu vector
    XX = norm.rvs(null_case, scale = 1, size = (power_iters, m))
    if m == r:
        cpch_f = cpch(XX, m, r, f_fisher, norm.pdf, norm.cdf, truncnorm.rvs, N) 
        return (cpch_f, cpch_f, cpch_f)
    else:
        cpch_f = cpch(XX, m, r, f_fisher, norm.pdf, norm.cdf, truncnorm.rvs, N) 
        cpch_b = cpch(XX, m, r, f_bonferroni, norm.pdf, norm.cdf, truncnorm.rvs, N)
        cpch_s = cpch(XX, m, r, f_simes, norm.pdf, norm.cdf, truncnorm.rvs, N) 
        return (cpch_f, cpch_s, cpch_b)
# Out:
# 231

# %%
#save a csv for each null case
for null_case in null_cases:
    #change path to where you want data to be saved
    path = 'Data/validity_analysis/m_' + str(m) + '_r_' + str(r) + '_mu_' + str(list(np.round(null_case, 3))).replace(', ', '_').replace('[', '').replace(']', '')
    isExist = os.path.exists(path)
    if not isExist:
        os.mkdir(path) 
    start = time.time()
    for iteration in np.arange(1, total_iters+1, 1):
        np.random.seed(int(iteration * 1000 + m * 100 + r))
        config =  'm=' + str(m) + ' , r=' + str(r) + ', locs=' + str(list(np.round(null_case, 3)))
        cpch_f, cpch_b, cpch_s = calculate_cpch(null_case, power_iters, m, r)
        df = pd.DataFrame({'iteration': np.repeat(iteration, power_iters)
                  , 'm': np.repeat(m, power_iters)
                  , 'r': np.repeat(r, power_iters)
                  , 'mu': np.repeat(str(list(np.round(null_case, 3))), power_iters)
                  , 'Configuration': np.repeat(config, power_iters)
                  , "cpch_f": cpch_f
                  , "cpch_s": cpch_s
                  , "cpch_b": cpch_b})
        df.to_csv(path + '/it_' + str(iteration) + '.csv', index = False)
    end = time.time()
    print ("Null Case " + str(null_case) + " Completed, Time elapsed:", (end - start)/60)
# Out:
# Null Case [0. 0. 0.] Completed, Time elapsed: 0.8482588847478231
# Null Case [0.  0.  0.2] Completed, Time elapsed: 0.7836943666140238
# Null Case [0.  0.  0.4] Completed, Time elapsed: 0.782640298207601
# Null Case [0.  0.  0.6] Completed, Time elapsed: 0.7956567327181499
# Null Case [0.  0.  0.8] Completed, Time elapsed: 0.8238782445589702
# Null Case [0. 0. 1.] Completed, Time elapsed: 0.7628264665603638
# Null Case [0.  0.  1.2] Completed, Time elapsed: 0.7689070502916971
# Null Case [0.  1.4 2.6] Completed, Time elapsed: 0.7464202841122946
# Null Case [0.  1.4 2.8] Completed, Time elapsed: 0.768406887849172
# Null Case [0.  1.4 3. ] Completed, Time elapsed: 0.7556350231170654
# Null Case [0.  1.4 3.2] Completed, Time elapsed: 0.7569186846415202
# Null Case [0.  1.4 3.4] Completed, Time elapsed: 0.7752044479052226
# Null Case [0.  1.4 3.6] Completed, Time elapsed: 0.762672499815623
# Null Case [0.  1.4 3.8] Completed, Time elapsed: 0.7526829640070597
# Null Case [0.  1.4 4. ] Completed, Time elapsed: 0.7873163501421611
# Null Case [0.  1.6 1.6] Completed, Time elapsed: 0.7428210814793904
# Null Case [0.  1.6 1.8] Completed, Time elapsed: 0.736508047580719
# Null Case [0.  1.6 2. ] Completed, Time elapsed: 0.7591075658798218
# Null Case [0.  1.6 2.2] Completed, Time elapsed: 0.7530203143755595
# Null Case [0.  1.6 2.4] Completed, Time elapsed: 0.7612572193145752
# Null Case [0.  1.6 2.6] Completed, Time elapsed: 0.7940515955289205
# Null Case [0.  1.6 2.8] Completed, Time elapsed: 0.7582189838091532
# Null Case [0.  1.6 3. ] Completed, Time elapsed: 0.7494967818260193
# Null Case [0.  1.6 3.2] Completed, Time elapsed: 0.782739516099294
# Null Case [0.  1.6 3.4] Completed, Time elapsed: 0.765098516146342
# Null Case [0.  1.6 3.6] Completed, Time elapsed: 0.7723936637242635
# Null Case [0.  1.6 3.8] Completed, Time elapsed: 0.7975433349609375
# Null Case [0.  1.6 4. ] Completed, Time elapsed: 0.8131510138511657
# Null Case [0.  1.8 1.8] Completed, Time elapsed: 0.8393339157104492
# Null Case [0.  1.8 2. ] Completed, Time elapsed: 0.806608768304189
# Null Case [0.  1.8 2.2] Completed, Time elapsed: 0.8417762001355489
# Null Case [0.  1.8 2.4] Completed, Time elapsed: 0.8370834310849508
# Null Case [0.  1.8 2.6] Completed, Time elapsed: 0.8625852624575298
# Null Case [0.  1.8 2.8] Completed, Time elapsed: 0.8086740493774414
# Null Case [0.  1.8 3. ] Completed, Time elapsed: 0.81948401927948
# Null Case [0.  1.8 3.2] Completed, Time elapsed: 0.8276478171348571
# Null Case [0.  1.8 3.4] Completed, Time elapsed: 0.8661750674247741
# Null Case [0.  1.8 3.6] Completed, Time elapsed: 1.2286899169286092
# Null Case [0.  1.8 3.8] Completed, Time elapsed: 1.450134030977885
# Null Case [0.  1.8 4. ] Completed, Time elapsed: 1.586495300134023
# Null Case [0. 2. 2.] Completed, Time elapsed: 1.4265625158945718
# Null Case [0.  2.  2.2] Completed, Time elapsed: 0.7996022661526998
# Null Case [0.  2.  2.4] Completed, Time elapsed: 0.8124313275019328
# Null Case [0.  2.  2.6] Completed, Time elapsed: 0.8138068000475566
# Null Case [0.  2.  2.8] Completed, Time elapsed: 0.8077333172162374
# Null Case [0. 2. 3.] Completed, Time elapsed: 0.8231274962425232
# Null Case [0.  2.  3.2] Completed, Time elapsed: 0.8260884722073872
# Null Case [0.  2.  3.4] Completed, Time elapsed: 0.8662475506464641
# Null Case [0.  2.  3.6] Completed, Time elapsed: 0.8620621879895528
# Null Case [0.  2.  3.8] Completed, Time elapsed: 0.8367571632067362
# Null Case [0. 2. 4.] Completed, Time elapsed: 0.8098182161649068
# Null Case [0.  2.2 2.2] Completed, Time elapsed: 0.7757855455080668
# Null Case [0.  2.2 2.4] Completed, Time elapsed: 0.7799665172894795
# Null Case [0.  2.2 2.6] Completed, Time elapsed: 0.7606654008229573
# Null Case [0.  2.2 2.8] Completed, Time elapsed: 0.7785258332888285
# Null Case [0.  2.2 3. ] Completed, Time elapsed: 0.7809425155321758
# Null Case [0.  2.2 3.2] Completed, Time elapsed: 0.8095141172409057
# Null Case [0.  2.2 3.4] Completed, Time elapsed: 0.8099039832750956
# Null Case [0.  2.2 3.6] Completed, Time elapsed: 0.8007971008618673
# Null Case [0.  2.2 3.8] Completed, Time elapsed: 0.7940929651260376
# Null Case [0.  2.2 4. ] Completed, Time elapsed: 0.8176430145899455
# Null Case [0.  2.4 2.4] Completed, Time elapsed: 0.7994134028752645
# Null Case [0.  2.4 2.6] Completed, Time elapsed: 0.8086384852727254
# Null Case [0.  2.4 2.8] Completed, Time elapsed: 0.8334856033325195
# Null Case [0.  2.4 3. ] Completed, Time elapsed: 0.8046088020006815
# Null Case [0.  2.4 3.2] Completed, Time elapsed: 0.8386311491330465
# Null Case [0.  2.4 3.4] Completed, Time elapsed: 0.8294215679168702
# Null Case [0.  2.4 3.6] Completed, Time elapsed: 0.8249586820602417
# Null Case [0.  2.4 3.8] Completed, Time elapsed: 0.8105473001797994
# Null Case [0.  2.4 4. ] Completed, Time elapsed: 0.8152365803718566
# Null Case [0.  2.6 2.6] Completed, Time elapsed: 0.840467898050944
# Null Case [0.  2.6 2.8] Completed, Time elapsed: 0.8080116311709086
# Null Case [0.  2.6 3. ] Completed, Time elapsed: 0.8322891354560852
# Null Case [0.  2.6 3.2] Completed, Time elapsed: 0.8290065328280131
# Null Case [0.  2.6 3.4] Completed, Time elapsed: 0.8217307527860006
# Null Case [0.  2.6 3.6] Completed, Time elapsed: 0.8934839169184366
# Null Case [0.  2.6 3.8] Completed, Time elapsed: 0.771892515818278
# Null Case [0.  2.6 4. ] Completed, Time elapsed: 0.7643576979637146
# Null Case [0.  2.8 2.8] Completed, Time elapsed: 0.7541507681210836
# Null Case [0.  2.8 3. ] Completed, Time elapsed: 0.7562395016352336
# Null Case [0.  2.8 3.2] Completed, Time elapsed: 0.750444785753886
# Null Case [0.  2.8 3.4] Completed, Time elapsed: 0.7456905682881673
# Null Case [0.  2.8 3.6] Completed, Time elapsed: 0.7392530322074891
# Null Case [0.  2.8 3.8] Completed, Time elapsed: 0.7525179783503214
# Null Case [0.  2.8 4. ] Completed, Time elapsed: 0.758415432771047
# Null Case [0. 3. 3.] Completed, Time elapsed: 0.7458143671353658
# Null Case [0.  3.  3.2] Completed, Time elapsed: 0.7401553829511006
# Null Case [0.  3.  3.4] Completed, Time elapsed: 0.7436696052551269
# Null Case [0.  3.  3.6] Completed, Time elapsed: 0.7452113310496012
# Null Case [0.  3.  3.8] Completed, Time elapsed: 0.7497922817866007
# Null Case [0. 3. 4.] Completed, Time elapsed: 0.746983019510905
# Null Case [0.  3.2 3.2] Completed, Time elapsed: 0.739941414197286
# Null Case [0.  3.2 3.4] Completed, Time elapsed: 0.7478111823399861
# Null Case [0.  3.2 3.6] Completed, Time elapsed: 0.7413859208424886
# Null Case [0.  3.2 3.8] Completed, Time elapsed: 0.7465136170387268
# Null Case [0.  3.2 4. ] Completed, Time elapsed: 0.7545146981875102
# Null Case [0.  3.4 3.4] Completed, Time elapsed: 0.7508844653765361
# Null Case [0.  3.4 3.6] Completed, Time elapsed: 0.7535389304161072
# Null Case [0.  3.4 3.8] Completed, Time elapsed: 0.753555953502655
# Null Case [0.  3.4 4. ] Completed, Time elapsed: 0.7411505540211996
# Null Case [0.  3.6 3.6] Completed, Time elapsed: 0.7626734495162963
# Null Case [0.  3.6 3.8] Completed, Time elapsed: 0.7327733476956685
# Null Case [0.  3.6 4. ] Completed, Time elapsed: 0.7398275136947632
# Null Case [0.  3.8 3.8] Completed, Time elapsed: 0.7500054200490316
# Null Case [0.  3.8 4. ] Completed, Time elapsed: 0.7580805500348409
# Null Case [0. 4. 4.] Completed, Time elapsed: 0.7672017812728882

# %%
#write script to knit together csvs across all iterations for each case, so will have config, and p-values
ks_f, ks_b, ks_s = [], [], []
for null_case in null_cases:
    path = 'Data/validity_analysis/m_' + str(m) + '_r_' + str(r) + '_mu_' + str(list(np.round(null_case, 3))).replace(', ', '_').replace('[', '').replace(']', '')
    li = []
    for filename in os.listdir(path):
        df = pd.read_csv(path + '/' + filename, index_col = None, header=0)
        li.append(df)
    df_final = pd.concat(li, axis = 0, ignore_index = True)
    df_final.to_csv('Data/final_data/m_' + str(m) + '_r_' + str(r) + '_mu_' + str(list(np.round(null_case, 3))).replace(', ', '_').replace('[', '').replace(']', '') + '.csv',
                   index = False)
    #get ks test statistic for each null case
    ks_f.append(scipy.stats.kstest(df_final['cpch_f'], 'uniform')[0])
    ks_s.append(scipy.stats.kstest(df_final['cpch_s'], 'uniform')[0])
    ks_b.append(scipy.stats.kstest(df_final['cpch_b'], 'uniform')[0])

# %%
#make dataset that combines all p-values for all null configurations for a given m and r
combined_data = []
#change path to where you want data to be saved
path = 'Data/final_data'
for filename in os.listdir(path):
    if not filename.startswith('.'):
        df = pd.read_csv(path + '/' + filename, index_col = None, header=0)
        combined_data.append(df)
df_combined = pd.concat(combined_data, axis = 0, ignore_index = True).sort_values(['Configuration', 'iteration'])
#change path to where you want data to be saved
df_combined.to_csv('Data/combined_data_m_' + str(m) + '_r_' + str(r) + '.csv',
                index = False)

# %%
#get ks statistics for a given m and r
ks_data = pd.DataFrame({'ks_f': ks_f, 'ks_b': ks_b, 'ks_s': ks_s})
ks_data.insert(0, 'm', m)
ks_data.insert(1, 'r', r)
ks_data.insert(2, 'mu', [str(list(np.round(null_case, 3))) for null_case in null_cases])
#ks_data['null_case'] = null_cases
config = ['m=' + str(m) + ' , r=' + str(r) + ', locs=' +str(list(np.round(null_case, 3))) for null_case in null_cases]
ks_data.insert(3, 'Configuration', config)
#change path to where you want data to be saved
ks_data.to_csv('Data/ks_df_m_' + str(m) + '_r_' + str(r) + '.csv', index = False)
